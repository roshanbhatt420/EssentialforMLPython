# %%
import numpy as np
import pandas as pd 
from sklearn import datasets 
import matplotlib.pyplot as plt

# %%
iris=datasets.load_iris()

# %%
x=iris.data
y=iris.target

# %%
names=iris.target_names

# %%
x.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
# creatign the dataframes
df=pd.DataFrame(x,columns=iris.feature_names)

# %%
df['species']=iris.target

# %%
df['species']=df['species'].replace(to_replace=[0,1,2], value=['setpsa','versicolor','virginia'])

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#       species
# 0      setpsa
# ...

# %%
# eda in datasets
import seaborn as sns

# %%
sns.pairplot(data=df, hue='species', palette='Set2')

# %%
#tranforming the data into the 3 d

# %%
# train test spilt functionality

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=3)

# %%
print(x_train.shape,y_train.shape)
# Out:
# (120, 4) (120,)

# %%
print(x_test.shape,y_test.shape)
# Out:
# (30, 4) (30,)

# %%
from sklearn.svm import SVC

# %% [markdown]
# svm=SVC(kernel='linear', random_state=0)

# %%
svm=SVC(kernel='linear', random_state=0)

# %%
svm.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
pred=svm.predict(x_test)

# %%
pred
# Out:
# array([0, 0, 0, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 2, 0, 2, 2, 2, 0, 2, 2,
#        2, 1, 0, 2, 2, 1, 1, 1])

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import  confusion_matrix

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9666666666666667

# %%
# if i want to print confusion matrics

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  1],
#        [ 0,  0, 10]], dtype=int64)

# %%
# making new karnel

# %%
rbf_svm=SVC(kernel='rbf',random_state=0)
